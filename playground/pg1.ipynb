# %%
import json
import sys
from pathlib import Path

# Ensure project root is importable when running from playground notebooks
project_root = Path.cwd().resolve().parent
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# %%
from lib.agentic.graph import AgenticGraph
from lib.agentic.utils.state_print import state_brief_print

workflow = AgenticGraph().build_workflow().compile()

# Auto loop test: question -> auto_answer -> ref -> question ... until max_round
state_q = {
    "question": "I am preparing for an ML Algorithm Engineer interview. Please generate the soft knowledge graph root node and start diagnostics.",
    "max_round": 2,
    "current_round": 0,
}
result = await workflow.ainvoke(state_q)
state_brief_print(result)
# Out:
# {'current_round': 2,
#  'max_round': 2,
#  'last_concept': 'Algorithms',
#  'last_score': 85.0,
#  'last_feedback': 'The answer provides a good definition of an algorithm and distinguishes it from '
#                   'a simple procedure, but it could benefit from more clarity on the systematic '
#                   'nature of algorithms and their efficiency. The example of sorting laundry is '
#                   'relevant but could be more explicitly tied to the concept of input and output.',
#  'last_ground_truth': 'An algorithm is a precise, step-by-step set of instructions designed to '
#                       'perform a specific task or solve a problem, often characterized by its '
#                       'efficiency and effectiveness. Unlike a simple procedure or recipe, which '
#                       'may lack a clear end goal or systematic approach, an algorithm is '
#                       'structured to produce a specific output from given inputs. An everyday '
# ...
